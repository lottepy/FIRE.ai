# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
from datetime import datetime, date
import calendar
import math

# %%
curr_path = Path(os.path.abspath('')).parent
doc_path = os.path.join(curr_path, 'data', 'policy', f"etf_mar2023.xlsx")
etf = pd.read_excel(doc_path, sheet_name='etf')

# %%
etf
# Out:
#     GSS TICKER Region                ISIN     PRIME ID          Ticker
# 0          GB5     AU  /isin/AU00000GOLD7  356118331.0  GOLD AU Equity
# 1         IAF1     AU  /isin/AU000000IAF5  362087319.0   IAF AU Equity
# 2        IEM12     AU  /isin/AU000000IEM3  360363269.0   IEM AU Equity
# 3          STW     AU  /isin/AU000000STW9  360010084.0   STW AU Equity
# 4         VAS1     AU  /isin/AU000000VAS1  360765489.0   VAS AU Equity
# ..         ...    ...                 ...          ...             ...
# 430        XBI     US  /isin/US78464A8707  357402959.0   XBI US Equity
# 431        XOP     US  /isin/US78468R5569  357403677.0   XOP US Equity
# 432        XRT     US  /isin/US78464A7147  357402962.0   XRT US Equity
# 433       XYLD     US  /isin/US37954Y4750  375060200.0  XYLD US Equity
# 434       ZROZ     US  /isin/US72201R8824  370362512.0  ZROZ US Equity
#
# [435 rows x 5 columns]
